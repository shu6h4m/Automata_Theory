# %% [markdown]
# # **Assignment 2**

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:
    
  #---- Leave these definitions ON if running on laptop
  #---- Else turn OFF by putting them between ''' ... '''

  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.LangDef   import *  #-- mainly for nthnumeric
from jove.Def_md2mc import *  #-- for md2mc
from jove.Def_DFA   import *  #-- for all DFA functions
from jove.DotBashers import * #-- for dotObj_dfa
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## Constructing a DFA that accepts all strings over { +, - } that contain the string ++-- in it.

# %%
myDFA = md2mc('''
DFA
IA : + -> B
IA : - -> IA

B : + -> C
B : - -> IA

C : + -> C
C : - -> D

D : + -> B
D : - -> FE
'''
)

# %%
print(myDFA)
# Out:
# {'Q': {'D', 'IA', 'C', 'FE', 'B'}, 'Sigma': {'+', '-'}, 'Delta': {('IA', '+'): 'B', ('IA', '-'): 'IA', ('B', '+'): 'C', ('B', '-'): 'IA', ('C', '+'): 'C', ('C', '-'): 'D', ('D', '+'): 'B', ('D', '-'): 'FE'}, 'q0': 'IA', 'F': {'FE'}}

# %%
dotObj_dfa(myDFA)

# %%
dotObj_dfa(myDFA, FuseEdges=True)

# %%
from jove.JoveEditor import *
JoveEditor(examples=True)
display(HTML('<link rel=\"stylesheet\" href=\"//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css\"/>'))
# Out:
# <style>textarea, input { font-family: monospace; }</style>
# ...
# <link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>
