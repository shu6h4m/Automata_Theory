# %% [markdown]
# <a href="https://colab.research.google.com/github/shu6h4m/Automata_Theory/blob/main/Final_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**◀[     The Final Assignment  ](https://classroom.google.com/u/1/c/Mzc5NjE2OTQwNzg0/a/NDI1MDU5NDQwMjQz/details)▶**

# %% [markdown]
# # Problem 1: Design an NFA for $\{0,1\}^* 1 0$ ("Ends 10")
#
# ## It will be a 3-state NFA, and name the states as I, S0, and F
#
# ### Document each line of your code with a short comment

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

# -- Detect if in Own Install or in Colab
try:
    import google.colab
    OWN_INSTALL = False
except:
    OWN_INSTALL = True
    
if OWN_INSTALL:
    
  #---- Leave these definitions ON if running on laptop
  #---- Else turn OFF by putting them between ''' ... '''

  sys.path[0:0] = ['../../../../..',  '../../../../../3rdparty',  
                   '../../../..',  '../../../../3rdparty',  
                   '../../..',     '../../../3rdparty', 
                   '../..',        '../../3rdparty',
                   '..',           '../3rdparty' ]

else: # In colab
  ! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
  sys.path.append('./Jove')
  sys.path.append('./Jove/jove')

# -- common imports --
from jove.DotBashers import *
from jove.Def_md2mc  import *
from jove.Def_NFA    import *
from jove.Def_DFA    import *
from jove.AnimateNFA import *
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
#Solution to problem 1
nfaEnds10 = md2mc('''
NFA

I : 0 -> I
I : 1 -> I

I : 1 -> S0
S0: 0 -> F

''')

#Print NFA
dotObj_nfa(nfaEnds10)

# %% [markdown]
# # Problem 2: Execute the cell below and follow the bulleted instructions
#
# * When the animation pane comes up, type in 10010 and Use Animate to illustate.

# %%
AnimateNFA(nfaEnds10, FuseEdges=False)
display(HTML('<link rel=\"stylesheet\" href=\"//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css\"/>'))
# Out:
# VBox(children=(HBox(children=(Text(value='', description='Input:', layout=Layout(width='500px'), placeholder='…
# <link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>

# %% [markdown]
# # Problem 3: Convert the NFA to a DFA (using an appropriate Jove Statement)

# %%
converted = nfa2dfa(nfaEnds10) #Convert given NFA to DFA
dotObj_dfa(converted)          #To print the DFA
